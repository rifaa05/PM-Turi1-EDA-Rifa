# %% [markdown]
# <a href="https://colab.research.google.com/github/rifaa05/MachineLearning/blob/main/PM_P3_Rifa'ahFatihatuSa'adah_2488010008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modul Praktikum — Pertemuan 3
# ## Eksplorasi Data (Exploratory Data Analysis)
#
# **Mata Kuliah:** Pembelajaran Mesin (INF62325) — 3 SKS
# **Program Studi:** S1 Informatika, UIN Siber Syekh Nurjati Cirebon
# **Sub-CPMK:** SCPMK0401-001
#
# ---
#
# ### Tujuan Praktikum
# Setelah menyelesaikan praktikum ini, Anda mampu:
# 1. Memuat dataset nyata ke dalam Python menggunakan pandas.
# 2. Memeriksa struktur, tipe data, dan statistik deskriptif dataset.
# 3. Mengidentifikasi nilai hilang (missing values) dan outlier.
# 4. Membuat visualisasi: histogram, box plot, scatter plot, dan heatmap korelasi.
# 5. Merangkum temuan EDA sebagai bekal tahap prapemrosesan.
#
# ### Petunjuk
# Jalankan setiap sel berurutan (`Shift + Enter`). Baca komentar pada tiap sel. Kerjakan bagian **Latihan** di akhir.

# %% [markdown]
# ## Latihan Mandiri
# **Latihan 1.** Muat dataset lain bawaan seaborn, yaitu `tips` (`sns.load_dataset('tips')`). Tampilkan `head()`, `shape`, dan `info()`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

tips = sns.load_dataset('tips')
tips.head()
print(tips.shape)
tips.info()
# Out:
# (244, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# **Latihan 2.** Pada dataset `tips`, buat histogram kolom `total_bill` dan box plot kolom `tip`. Amati sebaran dan outlier-nya.

# %%
tips[['total_bill']].hist(figsize=(9,6), bins=15)
plt.show()
sns.boxplot(data=tips[['tip']])
plt.title('Deteksi Outlier')
plt.show()

# %% [markdown]
# **Latihan 3.** Buat scatter plot `total_bill` (x) vs `tip` (y) pada dataset `tips`, diwarnai menurut kolom `time` (Lunch/Dinner). Apa yang dapat Anda simpulkan?

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=tips,
    x='total_bill',
    y='tip',
    hue='time'
)

plt.title('Total Bill vs Tip berdasarkan Time')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# **Latihan 4.** Buat heatmap korelasi untuk fitur numerik pada dataset `tips`. Pasangan fitur mana yang paling berkorelasi?

# %%
num = tips.select_dtypes(include='number')
sns.heatmap(num.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# ## Refleksi
# 1. Mengapa EDA penting dilakukan sebelum membangun model?
# 2. Apa perbedaan informasi yang Anda peroleh dari histogram, box plot, dan scatter plot?
# 3. Temuan EDA mana pada dataset Iris yang menurut Anda paling berguna untuk klasifikasi? Mengapa?
#
# ---
# *Jawaban Anda:*
#
# 1. karena EDA membantu kita memahami karakteristik dataset terlebih dahulu dan EDA membantu memastikan bahwa data sudah dipahami dan dipersiapkan dengan baik sebelum digunakan dalam proses pemodelan. Dengan begitu, kita tidak langsung membangun model menggunakan data yang belum dipahami.
# 2. perbedaan informasi dari histogram,box plot, dan scatter plot itu Histogram digunakan untuk melihat distribusi dan sebaran data dalam satu variabel. Box plot digunakan untuk melihat median, persebaran data, dan mendeteksi outlier. Sedangkan scatter plot digunakan untuk melihat hubungan antara dua variabel. Jadi, ketiganya memberikan informasi yang berbeda dan saling melengkapi dalam memahami data.
# 3. Temuan yang paling berguna adalah adanya perbedaan pola ukuran fitur antarspesies Iris, terutama pada petal_length dan petal_width.
# Iris-setosa cenderung memiliki ukuran petal yang jauh lebih kecil dibandingkan Iris-versicolor dan Iris-virginica. Sementara itu, versicolor dan virginica juga memiliki pola ukuran petal yang berbeda meskipun terdapat sedikit tumpang tindih. Hal tersebut penting untuk klasifikasi karena: Fitur yang memiliki perbedaan jelas antar kelas akan lebih mudah digunakan oleh model untuk membedakan kelas tersebut.

# %% [markdown]
# ## Pengumpulan
# 1. Jalankan seluruh sel (**Runtime → Run all**), pastikan tanpa error dan seluruh grafik tampil.
# 2. Lengkapi latihan mandiri , dan refleksi.
# 3. Simpan sebagai `PM_P3_NamaAnda_NIM.ipynb`, unduh `.ipynb`, unggah ke GitHub.
#
# ---
# **Kriteria penilaian (Praktikum 1 / TuRi 1 — bagian dari 25% komponen praktikum):** ketepatan kode & eksekusi 30%, pemahaman langkah 30%, interpretasi hasil 25%, kerapian laporan & kesimpulan 15%.
